# %%
import requests

token = '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'
url = 'https://raw.githubusercontent.com/EinarOlafsson/spacr/main/spacr_data_generation.py'
headers = {'Authorization': f'token {token}'}
response = requests.get(url, headers=headers)
with open('spacr_data_generation.py', 'w') as file:
    file.write(response.text)
    
import spacr_data_generation
# Out:
# Torch available: True
# CUDA version: 11.8

# %%
src = ""
preprocess_generate_masks(src, 
                          experiment='exp',
                          preprocess=True,
                          masks=True,
                          randomize=True,
                          batch_size=100, 
                          channels=[0,1,2,3],
                          remove_background=True,
                          backgrounds=[100,100,100], 
                          min_highs=[1000,1000,1000],
                          nucleus_dim=0, 
                          parasite_dim=2,
                          cell_dim=3, 
                          lower_quantile=0.02, 
                          signal_to_noise=5,
                          magnefication=40, 
                          cellprob_thresholds=[0,0,-1], 
                          save_ls=[True,True,True], 
                          merge_ls=[False,False,False],
                          count_ls=[False,False,False], 
                          timelapse=False, 
                          plot=False, 
                          examples_to_plot=10, 
                          normalize_plots=True, 
                          workers=30, 
                          verbose=True)
torch.cuda.empty_cache()
gc.collect()

# %%
src = ""
if __name__ == "__main__":
    settings = {'experiment':'exp',
                'input_folder':src+'/merged',
                'channels':[0,1,2,3],
                'cell_dim':4,
                'nuclei_dim':5,
                'parasite_dim':6,
                'cytoplasm':True,
                'save_arrays':False,
                'save_png':True,
                'crop_mode':['cell'],
                'center_crop':True,
                'png_size':[[224,224]],
                'normalize':(1,99),
                'normalize_percentiles':[1,99], 
                'png_dims':[0,1,2],
                'expand_nuclei':False,
                'expand_nuclei_by_px':5,
                'expand_parasite':False,
                'expand_parasite_by_px':5,
                'normalize_by':'png', #'fov' or 'png'
                'dialate_pngs':[False,False,False], #cell, nuclus, parasite
                'dialate_png_ratios':[0,0.2,0.2],
                'save_measurements':True,
                'plot':False,
                'plot_filtration':False,
                'include_uninfected':False,
                'merge_edge_parasite_cells':True,
                'radial_dist':True,
                'calculate_correlation':True,
                'manders_thresholds':[15,85,95],
                'homogeneity':True, 
                'homogeneity_distances':[8,16,32],
                'cell_min':2000,
                'nucleus_min':1000,
                'parasite_min':500,
                'cytoplasm_min':500,
                'max_workers':30}
    measure_crop(settings)

# %%
src = ""
df = analyze_recruitment(src,
                         target='protein_name',
                         plot=True,
                         save_filtered_filelist=False, #saves object filelist after image object filtration as filename_lable.
                         plot_nr=3,
                         cell_dim=4,
                         nucleus_dim=5,
                         parasite_dim=6,
                         plot_control=True,
                         filter_data=True,
                         mask_chans=[0,2,3], # (nucleus, parasite cell)
                         channel_of_interest=1,
                         cell_metadata_ls=['HeLa'], 
                         parasite_metadata_ls=['wt', 'ko'],
                         parasite_loc_ls=[['c1', 'c2'],['c3', 'c4']],
                         treatment_ls=['rep_1','rep_1'],
                         treatment_loc_ls=[['r1', 'r3'],['r2', 'r4']],
                         col_names=['col','col','row'], #(cell, parasite, treatment)
                         parasite_size_min=0,
                         nucleus_size_min=0,
                         cell_size_min=0,
                         parasite_min=0,
                         nucleus_min=0,
                         cell_min=0,
                         target_min=0,
                         size_quantiles=False,
                         cells_per_well=0,
                         include_noninfected=False,
                         include_multiinfected=True, #parasite per cell = 1
                         include_multinucleated=True, #nuclei per cell = 1
                         include_border_parasites=True, #only removes objects in image.
                         remove_background=True,
                         backgrounds=[100,100,100,100], 
                         channel_dims=[0,1,2,3],
                         figuresize=50)

# %%
src = ""
plot_merged(src+'/merged',
            cmap='inferno',
            cell_dim=4,
            nucleus_dim=5,
            parasite_dim=6,
            channel_dims=[0,1,2,3],
            figuresize=20,
            nr=3,
            print_object_number=True,
            normalize=True,
            normalization_percentiles=[1,99],
            overlay=True,
            overlay_chans=[3,2,0],
            outline_thickness=3,
            outline_color='gbr',
            backgrounds=[100,100,100,100],
            remove_background=True,
            filter_objects=True,
            filter_min_max=[[0,100000],[0,100000],[0,100000],[0,100000]],
            include_multinucleated=True,
            include_multiinfected=True,
            include_noninfected=True,
            include_border_parasites=True,
            interactive=False,
            verbose=True)

# %%
src = ""
annotate(db=src+'/measurements/measurements.db',
         image_type="cell_png", 
         channels=['r', 'g', 'b'],
         annotation_column='test',
         geom="3200x2000", 
         img_size=(200, 200), 
         rows=10, 
         columns=18)
